# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Preparando dados

# %%
hp_2015 = pd.read_csv('2015.csv')
hp_2016 = pd.read_csv('2016.csv')
hp_2017 = pd.read_csv('2017.csv')
hp_2018 = pd.read_csv('2018.csv')
hp_2019 = pd.read_csv('2019.csv')

# %%
hp_2018 = hp_2018.rename(columns={'Country or region': 'Country'})
hp_2019 = hp_2019.rename(columns={'Country or region': 'Country'})

# %%
hp_2015['Year'] = '2015'
hp_2016['Year'] = '2016'
hp_2017['Year'] = '2017'
hp_2018['Year'] = '2018'
hp_2019['Year'] = '2019'

# %% [markdown]
# #### Em todos:
# Country
# Year
# Happiness Rank
# Happiness Score
# GPD per capta
# Family
# Healthy Life Expectancy
# Freedom
# Generosity
# Corruption

# %% [markdown]
# ## 2015
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual', 'Year'],
#       dtype='object')

# %%
hp_2015.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual', 'Year'],
#       dtype='object')

# %%
hp_2015_correto = hp_2015.copy()

# %%
hp_2015_correto = hp_2015.drop(columns = ['Region',
                                          'Standard Error', 'Dystopia Residual'])

# %%
hp_2015_correto.columns
# Out:
# Index(['Country', 'Happiness Rank', 'Happiness Score',
#        'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
#        'Freedom', 'Trust (Government Corruption)', 'Generosity', 'Year'],
#       dtype='object')

# %%
hp_2015_correto.columns=["Country",
"Happiness Rank",
"Happiness Score",
"GPD per capta",
"Family",
"Healthy Life Expectancy",
"Freedom",
"Corruption",
"Generosity",
"Year"]

# %%
hp_2015_correto.head()
# Out:
#        Country  Happiness Rank  Happiness Score  GPD per capta   Family  \
# 0  Switzerland               1            7.587        1.39651  1.34951
# 1      Iceland               2            7.561        1.30232  1.40223
# 2      Denmark               3            7.527        1.32548  1.36058
# 3       Norway               4            7.522        1.45900  1.33095
# 4       Canada               5            7.427        1.32629  1.32261
#
#    Healthy Life Expectancy  Freedom  Corruption  Generosity  Year
# 0                  0.94143  0.66557     0.41978     0.29678  2015
# 1                  0.94784  0.62877     0.14145     0.43630  2015
# 2                  0.87464  0.64938     0.48357     0.34139  2015
# 3                  0.88521  0.66973     0.36503     0.34699  2015
# 4                  0.90563  0.63297     0.32957     0.45811  2015

# %% [markdown]
# ## 2016
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Lower Confidence Interval', 'Upper Confidence Interval',
#        'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
#        'Freedom', 'Trust (Government Corruption)', 'Generosity',
#        'Dystopia Residual', 'Year'],
#       dtype='object')

# %%
hp_2016.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Lower Confidence Interval', 'Upper Confidence Interval',
#        'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
#        'Freedom', 'Trust (Government Corruption)', 'Generosity',
#        'Dystopia Residual', 'Year'],
#       dtype='object')

# %%
hp_2016_correto = hp_2016.copy()

# %%
hp_2016_correto = hp_2016_correto.drop(columns = ["Region", "Lower Confidence Interval", "Upper Confidence Interval","Dystopia Residual"])

# %%
hp_2016_correto.columns=["Country",
"Happiness Rank",
"Happiness Score",
"GPD per capta",
"Family",
"Healthy Life Expectancy",
"Freedom",
"Corruption",
"Generosity",
"Year"]

# %%
hp_2016_correto.head()
# Out:
#        Country  Happiness Rank  Happiness Score  GPD per capta   Family  \
# 0      Denmark               1            7.526        1.44178  1.16374
# 1  Switzerland               2            7.509        1.52733  1.14524
# 2      Iceland               3            7.501        1.42666  1.18326
# 3       Norway               4            7.498        1.57744  1.12690
# 4      Finland               5            7.413        1.40598  1.13464
#
#    Healthy Life Expectancy  Freedom  Corruption  Generosity  Year
# 0                  0.79504  0.57941     0.44453     0.36171  2016
# 1                  0.86303  0.58557     0.41203     0.28083  2016
# 2                  0.86733  0.56624     0.14975     0.47678  2016
# 3                  0.79579  0.59609     0.35776     0.37895  2016
# 4                  0.81091  0.57104     0.41004     0.25492  2016

# %% [markdown]
# ## 2017
# Index(['Country', 'Happiness.Rank', 'Happiness.Score', 'Whisker.high',
#        'Whisker.low', 'Economy..GDP.per.Capita.', 'Family',
#        'Health..Life.Expectancy.', 'Freedom', 'Generosity',
#        'Trust..Government.Corruption.', 'Dystopia.Residual', 'Year'],
#       dtype='object')

# %%
hp_2017.columns
# Out:
# Index(['Country', 'Happiness.Rank', 'Happiness.Score', 'Whisker.high',
#        'Whisker.low', 'Economy..GDP.per.Capita.', 'Family',
#        'Health..Life.Expectancy.', 'Freedom', 'Generosity',
#        'Trust..Government.Corruption.', 'Dystopia.Residual', 'Year'],
#       dtype='object')

# %%
hp_2017_correto = hp_2017.copy()

# %%
hp_2017_correto = hp_2017_correto.drop(columns = ["Whisker.high",
                                                  "Whisker.low", 
                                                  "Dystopia.Residual"])

# %%
hp_2017_correto.head()
# Out:
#        Country  Happiness.Rank  Happiness.Score  Economy..GDP.per.Capita.  \
# 0       Norway               1            7.537                  1.616463
# 1      Denmark               2            7.522                  1.482383
# 2      Iceland               3            7.504                  1.480633
# 3  Switzerland               4            7.494                  1.564980
# 4      Finland               5            7.469                  1.443572
#
#      Family  Health..Life.Expectancy.   Freedom  Generosity  \
# 0  1.533524                  0.796667  0.635423    0.362012
# 1  1.551122                  0.792566  0.626007    0.355280
# 2  1.610574                  0.833552  0.627163    0.475540
# 3  1.516912                  0.858131  0.620071    0.290549
# 4  1.540247                  0.809158  0.617951    0.245483
#
#    Trust..Government.Corruption.  Year
# 0                       0.315964  2017
# 1                       0.400770  2017
# ...

# %%
hp_2017_correto.columns=["Country",
"Happiness Rank",
"Happiness Score",
"GPD per capta",
"Family",
"Healthy Life Expectancy",
"Freedom",
"Generosity",
"Corruption",
"Year"]

# %%
hp_2017_correto.head()
# Out:
#        Country  Happiness Rank  Happiness Score  GPD per capta    Family  \
# 0       Norway               1            7.537       1.616463  1.533524
# 1      Denmark               2            7.522       1.482383  1.551122
# 2      Iceland               3            7.504       1.480633  1.610574
# 3  Switzerland               4            7.494       1.564980  1.516912
# 4      Finland               5            7.469       1.443572  1.540247
#
#    Healthy Life Expectancy   Freedom  Generosity  Corruption  Year
# 0                 0.796667  0.635423    0.362012    0.315964  2017
# 1                 0.792566  0.626007    0.355280    0.400770  2017
# 2                 0.833552  0.627163    0.475540    0.153527  2017
# 3                 0.858131  0.620071    0.290549    0.367007  2017
# 4                 0.809158  0.617951    0.245483    0.382612  2017

# %% [markdown]
# ## 2018
# Index(['Overall rank', 'Country', 'Score', 'GDP per capita', 'Social support',
#        'Healthy life expectancy', 'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Year'],
#       dtype='object')

# %%
hp_2018.columns
# Out:
# Index(['Overall rank', 'Country', 'Score', 'GDP per capita', 'Social support',
#        'Healthy life expectancy', 'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Year'],
#       dtype='object')

# %%
hp_2018.head()
# Out:
#    Overall rank      Country  Score  GDP per capita  Social support  \
# 0             1      Finland  7.632           1.305           1.592
# 1             2       Norway  7.594           1.456           1.582
# 2             3      Denmark  7.555           1.351           1.590
# 3             4      Iceland  7.495           1.343           1.644
# 4             5  Switzerland  7.487           1.420           1.549
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.874                         0.681       0.202
# 1                    0.861                         0.686       0.286
# 2                    0.868                         0.683       0.284
# 3                    0.914                         0.677       0.353
# 4                    0.927                         0.660       0.256
#
#    Perceptions of corruption  Year
# 0                      0.393  2018
# 1                      0.340  2018
# ...

# %%
hp_2018_correto = hp_2018.copy()

# %%
hp_2018_correto.columns=[
    "Happiness Rank",
    "Country",
    "Happiness Score",
    "GPD per capta",
    "Family",
    "Healthy Life Expectancy",
    "Freedom",
    "Generosity",
    "Corruption",
    "Year"]

## Family = Social Support

# %% [markdown]
# ## 2019
# Index(['Overall rank', 'Country', 'Score', 'GDP per capita', 'Social support',
#        'Healthy life expectancy', 'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Year'],
#       dtype='object')

# %%
hp_2019.columns
# Out:
# Index(['Overall rank', 'Country', 'Score', 'GDP per capita', 'Social support',
#        'Healthy life expectancy', 'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Year'],
#       dtype='object')

# %%
hp_2019_correto = hp_2019.copy()

# %%
hp_2019_correto.columns=[
    "Happiness Rank",
    "Country",
    "Happiness Score",
    "GPD per capta",
    "Family",
    "Healthy Life Expectancy",
    "Freedom",
    "Generosity",
    "Corruption",
    "Year"]

# %%
hp_2019_correto.head()
# Out:
#    Happiness Rank      Country  Happiness Score  GPD per capta  Family  \
# 0               1      Finland            7.769          1.340   1.587
# 1               2      Denmark            7.600          1.383   1.573
# 2               3       Norway            7.554          1.488   1.582
# 3               4      Iceland            7.494          1.380   1.624
# 4               5  Netherlands            7.488          1.396   1.522
#
#    Healthy Life Expectancy  Freedom  Generosity  Corruption  Year
# 0                    0.986    0.596       0.153       0.393  2019
# 1                    0.996    0.592       0.252       0.410  2019
# 2                    1.028    0.603       0.271       0.341  2019
# 3                    1.026    0.591       0.354       0.118  2019
# 4                    0.999    0.557       0.322       0.298  2019

# %% [markdown]
# ## Concatenando

# %%
groups = pd.concat(objs = [hp_2015_correto, hp_2016_correto, hp_2017_correto, hp_2018_correto, hp_2019_correto], ignore_index = True)

# %%
groups.head()
# Out:
#        Country  Happiness Rank  Happiness Score  GPD per capta   Family  \
# 0  Switzerland               1            7.587        1.39651  1.34951
# 1      Iceland               2            7.561        1.30232  1.40223
# 2      Denmark               3            7.527        1.32548  1.36058
# 3       Norway               4            7.522        1.45900  1.33095
# 4       Canada               5            7.427        1.32629  1.32261
#
#    Healthy Life Expectancy  Freedom  Corruption  Generosity  Year
# 0                  0.94143  0.66557     0.41978     0.29678  2015
# 1                  0.94784  0.62877     0.14145     0.43630  2015
# 2                  0.87464  0.64938     0.48357     0.34139  2015
# 3                  0.88521  0.66973     0.36503     0.34699  2015
# 4                  0.90563  0.63297     0.32957     0.45811  2015

# %%
groups.shape
# Out:
# (782, 10)

# %%
groups.tail()
# Out:
#                       Country  Happiness Rank  Happiness Score  GPD per capta  \
# 777                    Rwanda             152            3.334          0.359
# 778                  Tanzania             153            3.231          0.476
# 779               Afghanistan             154            3.203          0.350
# 780  Central African Republic             155            3.083          0.026
# 781               South Sudan             156            2.853          0.306
#
#      Family  Healthy Life Expectancy  Freedom  Corruption  Generosity  Year
# 777   0.711                    0.614    0.555       0.411       0.217  2019
# 778   0.885                    0.499    0.417       0.147       0.276  2019
# 779   0.517                    0.361    0.000       0.025       0.158  2019
# 780   0.000                    0.105    0.225       0.035       0.235  2019
# 781   0.575                    0.295    0.010       0.091       0.202  2019

# %%
groups.set_index(["Country", "Year"])
# Out:
#                                Happiness Rank  Happiness Score  GPD per capta  \
# Country                  Year
# Switzerland              2015               1            7.587        1.39651
# Iceland                  2015               2            7.561        1.30232
# Denmark                  2015               3            7.527        1.32548
# Norway                   2015               4            7.522        1.45900
# Canada                   2015               5            7.427        1.32629
# ...                                       ...              ...            ...
# Rwanda                   2019             152            3.334        0.35900
# Tanzania                 2019             153            3.231        0.47600
# Afghanistan              2019             154            3.203        0.35000
# Central African Republic 2019             155            3.083        0.02600
# South Sudan              2019             156            2.853        0.30600
#
# ...

# %%
groups.to_csv("Dataframe_Concatenado.csv")
